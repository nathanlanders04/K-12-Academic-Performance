# %% [markdown]
# # Intro

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd
import torch
import random
import sqlite3
import numpy as np

# %%
# set seed
random.seed(255)

# %% [markdown]
# # Create CSV

# %%
df_povbydist = pd.read_sql("""
  SELECT state,
    district_id,
    poverty_estimates.*
  FROM public_schools
  JOIN poverty_estimates
  USING(school_id)
""", db)

# %%
display(df_povbydist.head(3))

# %%
df_povbydist = df_povbydist.drop(["state", "school_id", "school_name", "income_to_poverty_ratio_standard_error"], axis = 1)
print(df_povbydist.head(3))

# %%
df_povbydist = df_povbydist.groupby("district_id").mean()
print(df_povbydist.head(3))

# %%
df_povbydist['income_to_poverty_ratio_estimate'] = df_povbydist['income_to_poverty_ratio_estimate'].apply(pd.to_numeric)
print(df_povbydist.head(3))

# %%
df_povbydist = df_povbydist.reset_index()
print(df_povbydist.head(3))

# %%
df_povbydist['district_id'] = df_povbydist['district_id'].apply(lambda x: '{:0>7}'.format(x))
print(df_povbydist.head(3))

# %%
df_povbydist.to_csv("/content/drive/MyDrive/Datasets/povertyByDistrict18_19.csv", header = True)
